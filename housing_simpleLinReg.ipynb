# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data= pd.read_csv('housing-classification-iter-0-2.csv')
data.columns
# Out:
# Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch', 'Expensive'],
#       dtype='object')

# %%
data.shape
# Out:
# (1460, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LotArea       1460 non-null   int64
#  1   LotFrontage   1201 non-null   float64
#  2   TotalBsmtSF   1460 non-null   int64
#  3   BedroomAbvGr  1460 non-null   int64
#  4   Fireplaces    1460 non-null   int64
#  5   PoolArea      1460 non-null   int64
#  6   GarageCars    1460 non-null   int64
#  7   WoodDeckSF    1460 non-null   int64
#  8   ScreenPorch   1460 non-null   int64
#  9   Expensive     1460 non-null   int64
# dtypes: float64(1), int64(9)
# memory usage: 114.2 KB

# %%
data.isnull().sum()
# Out:
# LotArea           0
# LotFrontage     259
# TotalBsmtSF       0
# BedroomAbvGr      0
# Fireplaces        0
# PoolArea          0
# GarageCars        0
# WoodDeckSF        0
# ScreenPorch       0
# Expensive         0
# dtype: int64

# %%
#Drop 'LotFrontage' Columns
data.drop(columns=['LotFrontage'],axis=1,inplace=True)

# %%
data.shape
# Out:
# (1460, 9)

# %%
#correlation of matrix
plt.figure(figsize=(16,8))
sns.heatmap(data.corr(),annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot: >

# %%
sns.kdeplot(data=data['Expensive'],shade=True)
# Out:
# C:\Users\siv7s\AppData\Local\Temp\ipykernel_26596\877691041.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=data['Expensive'],shade=True)
# <AxesSubplot: xlabel='Expensive', ylabel='Density'>

# %%
data['Expensive'].describe()
# Out:
# count    1460.000000
# mean        0.148630
# std         0.355845
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: Expensive, dtype: float64

# %%
#input features for model
X=data.drop(['Expensive'],axis=1)
#output features for model
y=data['Expensive']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
print("By using Linear Regression we got:")
print("Training data accuracy",lr_model.score(X_train, y_train))
print("Testing data accuracy",lr_model.score(X_test, y_test))
# Out:
# By using Linear Regression we got:
# Training data accuracy 0.3693980562443939
# Testing data accuracy 0.23456373441233924
